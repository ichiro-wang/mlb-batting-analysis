# %% [markdown]
# # Outlier Detection

# %%
# allow importing src module
import sys
import os

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

from src.data_loader import load_cleaned_data
from src.outlier_detection import OutlierDetector

# %% [markdown]
# ## Load Cleaned Data

# %%
data = load_cleaned_data()
data = data.drop(columns=["Performance Tier"])

reference_data = load_cleaned_data(reference_data=True)
# Out:
# Loading cleaned data from '../data/processed/batting_2015_2024_cleaned.csv'
# Loading reference data from '../data/processed/batting_2015_2024_reference.csv'

# %% [markdown]
# ## Isolation Forest
#
# For the first outlier detection method, we will try an **Isolation Forest**. Our dataset is highly dimensional, and Isolation Forests work well with such data.

# %%
detector = OutlierDetector(method="iso_forest", contamination="auto")
results = detector.analyze_outliers(data, reference_data)
detector.outlier_summary()
# Out:
# Summary of outliers
# Total number of samples: 2865
# Number of outliers: 35, Proportion of outliers: 0.012216404886561954
# Top outliers:
#                 Name  Season Team   wRC+
# 2541     Aaron Judge    2024  NYY  220.0
# 1896     Aaron Judge    2022  NYY  206.0
# 0       Bryce Harper    2015  WSN  197.0
# 937       Mike Trout    2018  LAA  188.0
# 936     Mookie Betts    2018  BOS  185.0
# 1904  Yordan Alvarez    2022  HOU  185.0
# 2216   Shohei Ohtani    2023  LAA  181.0
# 2544       Juan Soto    2024  NYY  181.0
# 622       Mike Trout    2017  LAA  180.0
# 2543   Shohei Ohtani    2024  LAD  179.0
# Bottom outliers:
#                    Name  Season Team   wRC+
# 2207     Cristian Pache    2022  OAK   33.0
# 968      Matt Carpenter    2018  STL  140.0
# 632    Charlie Blackmon    2017  COL  142.0
# 1330         Joey Gallo    2019  TEX  144.0
# 14          Chris Davis    2015  BAL  149.0
# 1603      Shohei Ohtani    2021  LAA  150.0
# 333          Joey Votto    2016  CIN  158.0
# 623   Giancarlo Stanton    2017  MIA  158.0
# 1250     Cody Bellinger    2019  LAD  161.0
# 2217         Matt Olson    2023  ATL  162.0

# %% [markdown]
# ### Checking Outliers
#
# Taking a look at who our outliers are and how well (or poor) they performed
